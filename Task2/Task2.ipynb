# %%
##Libraries Used

# %%
import cv2
import numpy as np
import math
import os
import copy

# %%
## Creation of Gaussian Kernel##

# %%
def gaussian_Kernel(x):
    sigma = x
    #print(sigma)
    su = 0.0
    s = 2.0*sigma*sigma
    G_K = [ ]
    for x in range (-3,4): # row
        row =[]
        for y in range(-3,4):# col
           # k =[y,-(x)] #<col,-<row>>
            x1 =  (y) # row
            y1 = -(x) # 
           # print([x,y])
            r = math.sqrt(x1*x1+y1*y1)
            temp = (math.exp(-(r*r)/s))/(math.pi*s)
            su+=temp
            row.append(temp)
        G_K.append(row)            
    #print(G_K)
    #print('sum is ',su)
    return (G_K,su)

# %%
#def oct_list(image):
  #  o = list()
    #img_l =octave_Img(image,G_K1)
    #o.append(np.asarray(octave_Img(image,G_K1))
   # o.append(np.asarray(image))
    #return o

# %%
## Resizing the Image According to the octave

# %%
def resize(image,ctr): 
    img_r = image.copy()
    if(ctr!=0):
        img_r = img_r[::2,::2]
    elif():
        img_r = image.copy()
    return img_r

# %%
#Covolution Process to create gaussian Images

# %%
def octave_Img(img_p,G_K1): # this is the convolution method which calculate the image and kernel 
    w = G_K1
    img_r = img_p.copy()
    img_2 = img_p.copy()
    d = img_r.shape
    height = img_r.shape[0]
    width  = img_r.shape[1] 
    print('Image Height  :',height)
    print('Image width   :',width)
    x1=0
    id_x =1
    for x in range (3,height-3): # row
        for y in range (3,width-3):# col
            su=0
            for k in range (-3,4):
                for l in range (-3,4):
                    a = img_r.item(x+k,y+l)
                    w1 = w[3+k][3+l];
                    su = su + (w1*a);              
                b = su;
                #img_2.itemset((x,y),b);
                img_2[x,y] =b
    
    
    #ot_list(img_2)
    #return(o.append(np.asarray(image)))
    return (img_2)
    #convolution

# %%
# Creating Keypoints

# %%
# keypoints
def keypoint(image,D1,D2,D3,x): ## the function to caluclate the keypoints of the DoG
    for i in range (1,len(np.asarray(D2))-1):
        m_x = D2[i]
        for j in range (1,len(m_x)-1):
            m_y =m_x[j]
            nei =[]
            for k in range(1,-2,-1):
                for l in range(-1,2,1):
                    nei.append(D1[i+1][j+k]) # getting the neighbouring values of D1
                    nei.append(D2[i+1][j+k]) # getting the neighbouring values of D2
                    nei.append(D3[i+1][j+k]) # getting the neighbouring values of D3
            maximum = max(nei)
            minimum = min(nei)
            if((m_y == maximum) or (m_y == minimum)): # checking whether the value os maximum or minimum
                if(x==1 or x==2):
                    print('keypoints for octave 1',[i,j]) 
                    image[i][j] = 255
                elif(x ==3 or x==4):
                    print('keypoints for octave 2',[i,j])
                    image[i*2][j*2] =255
                elif(x==5 or x==6):
                        print('keypoints for octave 3',[i,j])
                    image[i*4][j*4] =255
                elif(x==7 or x ==8):
                    print('keypoints for octave 4',[i,j])
                    image[i*8][j*8] =255        
    return(image)

# %%
#main Program

# %%
#main Program
img = cv2.imread('A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2.jpg',0)
img_dog = img.copy()
img_k =img.copy()
sigma = (1/(math.sqrt(2)))
res_list =list()
li =list()
img_g = list()
s=1
x=1
id_x =1
for oc in range(0,4):
    sigma1 = sigma
    img_p = resize(img,oc)
    for x in range(0,5):
        (G_K1,Su_N)= gaussian_Kernel(sigma) #calling gaussain kernel
        #cv2.namedWindow('image', cv2.WINDOW_NORMAL)
        #cv2.imshow('gi',np.asarray(G_K1))
        #cv2.waitKey(0)
        img_ga = octave_Img(img_p,G_K1) # calling octave_Img for caluclating the convolution
        #img_g = oct_list(img_p,G_K1,id_x)
        #img_gn = np.abs(img_ga)/np.max(np.abs(img_ga))
        img_g.append(np.asarray(img_ga))
        
        G_name = 'gaussian'+str(id_x)+'.jpg'
        id_x+=1
        path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
        cv2.imwrite(os.path.join(path,G_name),np.asarray(img_ga,dtype='uint8'))
        sigma = sigma * (math.sqrt(2))
    sigma =sigma1
    sigma = sigma * (math.sqrt(2))
    img =img_p.copy()
    res_list.append(np.asarray(img_p))
    #########################################################
    #list
print('=========dog==========')
print(len(img_g))
img_d1 =list()
img_d2 = list()
img_d3 = list()
img_d4 = list()
for i in range(0,4):
    print('start')
    img_dog = img_g[i]-img_g[i+1]
    img_gn = np.abs(img_dog)/np.max(np.abs(img_dog))
    img_d1.append(img_gn)
    #cv2.namedWindow('image', cv2.WINDOW_NORMAL)
    #cv2.imshow('image',img_dog)
    #cv2.waitKey(0)
    G_name = 'DOG'+str(i)+'.jpg'
    path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
    cv2.imwrite(os.path.join(path,G_name),np.asarray(img_gn,dtype='uint8'))
    print('end') 
 ######################################################################
 # keypoint for octave 1 [for D1,D2,D3]
image0 = keypoint(img_k,img_d1[0],img_d1[1],img_d1[2],1)
G_name = 'k1.jpg'
path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
cv2.imwrite(os.path.join(path,G_name),image0)
# keypoint for octave 1 [for D2,D3,D4]
image00 =keypoint(img_k,img_d1[1],img_d1[2],img_d1[3],2)
G_name = 'k2.jpg'
path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
cv2.imwrite(os.path.join(path,G_name),image00)

for i in range(5,9):
    print('start')
    img_dog = img_g[i]-img_g[i+1]
    img_gn = np.abs(img_dog)/np.max(np.abs(img_dog))
    img_d2.append(img_gn)
    G_name = 'DOG'+str(i)+'.jpg'
    path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
    cv2.imwrite(os.path.join(path,G_name),np.asarray(img_gn,dtype ='uint8'))
    print('end')
# keypoint for octave 2 [for D1,D2,D3]
image1=keypoint(img_k,img_d2[0],img_d2[1],img_d2[2],3)
path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
G_name = 'k3.jpg'
cv2.imwrite(os.path.join(path,G_name),np.asarray(image1,dtype ='uint8'))

# keypoint for octave 2 [for D2,D3,D4]
image2=keypoint(img_k,img_d2[1],img_d2[2],img_d2[3],4)
path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
G_name = 'k4.jpg'
cv2.imwrite(os.path.join(path,G_name),np.asarray(image2,dtype ='uint8'))

for i in range(10,14):
    print('start')
    img_dog = img_g[i]-img_g[i+1]
    img_gn = np.abs(img_dog)/np.max(np.abs(img_dog))
    img_d3.append(img_gn)
    G_name = 'DOG'+str(i)+'.jpg'
    path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
    cv2.imwrite(os.path.join(path,G_name),np.asarray(img_gn,dtype ='uint8'))
    print('end')
# keypoint for octave 3 [for D1,D2,D3]
image3 =keypoint(img_k,img_d3[0],img_d3[1],img_d3[2],5)
G_name = 'k5.jpg'
path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
cv2.imwrite(os.path.join(path,G_name),np.asarray(image3,dtype ='uint8'))
# keypoint for octave 3 [for D2,D3,D4]
image4=keypoint(img_k,img_d3[1],img_d3[2],img_d3[3],6)
G_name = 'k6.jpg'
path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
cv2.imwrite(os.path.join(path,G_name),np.asarray(image4,dtype ='uint8'))
    
for i in range(15,19):
    print('start')
    img_dog = img_g[i]-img_g[i+1]
    img_gn = np.abs(img_dog)/np.max(np.abs(img_dog))
    img_d4.append(img_gn)
    G_name = 'DOG'+str(i)+'.jpg'
    path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
    cv2.imwrite(os.path.join(path,G_name),np.asarray(img_gn,dtype ='uint8'))
    print('end')

# keypoint for octave 4 [for D1,D2,D3]
image5 =keypoint(img_k,img_d4[0],img_d4[1],img_d4[2],7)
G_name = 'k7.jpg'
path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
cv2.imwrite(os.path.join(path,G_name),np.asarray(image5,dtype ='uint8'))

# keypoint for octave 4 [for D2,D3,D4]
image6 =keypoint(img_k,img_d4[1],img_d4[2],img_d4[3],8)
G_name = 'k8.jpg'
path = 'A:\\classes\\Intro to Computer vision and Image Processing\\projrct\\project1\\task2\\images'
cv2.imwrite(os.path.join(path,G_name),np.asarray(image6,dtype ='uint8'))


# keypoints
# Out:
# Image Height  : 458
# Image width   : 750
# Image Height  : 458
# Image width   : 750
# Image Height  : 458
# Image width   : 750
# Image Height  : 458
# Image width   : 750
# Image Height  : 458
# Image width   : 750
# Image Height  : 229
# Image width   : 375
# Image Height  : 229
# Image width   : 375
# Image Height  : 229
# Image width   : 375
# Image Height  : 229
# Image width   : 375
# Image Height  : 229
# Image width   : 375
# Image Height  : 115
# Image width   : 188
# Image Height  : 115
# Image width   : 188
# Image Height  : 115
# Image width   : 188
# Image Height  : 115
# Image width   : 188
# Image Height  : 115
# Image width   : 188
# Image Height  : 58
# Image width   : 94
# Image Height  : 58
# Image width   : 94
# Image Height  : 58
# Image width   : 94
# Image Height  : 58
# Image width   : 94
# Image Height  : 58
# Image width   : 94
# =========dog==========
# 20
# start
# end
# start
# end
# start
# end
# start
# end
# keypoints for octave 1 [1, 1]
# keypoints for octave 1 [1, 2]
# keypoints for octave 1 [1, 3]
# keypoints for octave 1 [1, 4]
# keypoints for octave 1 [1, 5]
# keypoints for octave 1 [1, 6]
# keypoints for octave 1 [1, 7]
# keypoints for octave 1 [1, 8]
# keypoints for octave 1 [1, 9]
# keypoints for octave 1 [1, 10]
# keypoints for octave 1 [1, 11]
# keypoints for octave 1 [1, 12]
# keypoints for octave 1 [1, 13]
# keypoints for octave 1 [1, 14]
# keypoints for octave 1 [1, 15]
# keypoints for octave 1 [1, 16]
# keypoints for octave 1 [1, 17]
# keypoints for octave 1 [1, 18]
# keypoints for octave 1 [1, 19]
# keypoints for octave 1 [1, 20]
# keypoints for octave 1 [1, 21]
# keypoints for octave 1 [1, 22]
# keypoints for octave 1 [1, 23]
# keypoints for octave 1 [1, 24]
# keypoints for octave 1 [1, 25]
# keypoints for octave 1 [1, 26]
# keypoints for octave 1 [1, 27]
# keypoints for octave 1 [1, 28]
# keypoints for octave 1 [1, 29]
# keypoints for octave 1 [1, 30]
# keypoints for octave 1 [1, 31]
# keypoints for octave 1 [1, 32]
# keypoints for octave 1 [1, 33]
# keypoints for octave 1 [1, 34]
# keypoints for octave 1 [1, 35]
# keypoints for octave 1 [1, 36]
# keypoints for octave 1 [1, 37]
# keypoints for octave 1 [1, 38]
# keypoints for octave 1 [1, 39]
# keypoints for octave 1 [1, 40]
# keypoints for octave 1 [1, 41]
# keypoints for octave 1 [1, 42]
# keypoints for octave 1 [1, 43]
# keypoints for octave 1 [1, 44]
# keypoints for octave 1 [1, 45]
# keypoints for octave 1 [1, 46]
# keypoints for octave 1 [1, 47]
# keypoints for octave 1 [1, 48]
# keypoints for octave 1 [1, 49]
# keypoints for octave 1 [1, 50]
# keypoints for octave 1 [1, 51]
# keypoints for octave 1 [1, 52]
# keypoints for octave 1 [1, 53]
# keypoints for octave 1 [1, 54]
# keypoints for octave 1 [1, 55]
# keypoints for octave 1 [1, 56]
# keypoints for octave 1 [1, 57]
# keypoints for octave 1 [1, 58]
# keypoints for octave 1 [1, 59]
# keypoints for octave 1 [1, 60]
# keypoints for octave 1 [1, 61]
# keypoints for octave 1 [1, 62]
# keypoints for octave 1 [1, 63]
# keypoints for octave 1 [1, 64]
# keypoints for octave 1 [1, 65]
# keypoints for octave 1 [1, 66]
# keypoints for octave 1 [1, 67]
# keypoints for octave 1 [1, 68]
# keypoints for octave 1 [1, 69]
# keypoints for octave 1 [1, 70]
# keypoints for octave 1 [1, 71]
# keypoints for octave 1 [1, 72]
# keypoints for octave 1 [1, 73]
# keypoints for octave 1 [1, 74]
# keypoints for octave 1 [1, 75]
# keypoints for octave 1 [1, 76]
# keypoints for octave 1 [1, 77]
# keypoints for octave 1 [1, 78]
# keypoints for octave 1 [1, 79]
# keypoints for octave 1 [1, 80]
# keypoints for octave 1 [1, 81]
# keypoints for octave 1 [1, 82]
# keypoints for octave 1 [1, 83]
# keypoints for octave 1 [1, 84]
# keypoints for octave 1 [1, 85]
# keypoints for octave 1 [1, 86]
# keypoints for octave 1 [1, 87]
# keypoints for octave 1 [1, 88]
# keypoints for octave 1 [1, 89]
# keypoints for octave 1 [1, 90]
# keypoints for octave 1 [1, 91]
# keypoints for octave 1 [1, 92]
# keypoints for octave 1 [1, 93]
# keypoints for octave 1 [1, 94]
# keypoints for octave 1 [1, 95]
# keypoints for octave 1 [1, 96]
# keypoints for octave 1 [1, 97]
# keypoints for octave 1 [1, 98]
# keypoints for octave 1 [1, 99]
# keypoints for octave 1 [1, 100]
# keypoints for octave 1 [1, 101]
# keypoints for octave 1 [1, 102]
# keypoints for octave 1 [1, 103]
# keypoints for octave 1 [1, 104]
# keypoints for octave 1 [1, 105]
# keypoints for octave 1 [1, 106]
# keypoints for octave 1 [1, 107]
# keypoints for octave 1 [1, 108]
# keypoints for octave 1 [1, 109]
# keypoints for octave 1 [1, 110]
# keypoints for octave 1 [1, 111]
# keypoints for octave 1 [1, 112]
# keypoints for octave 1 [1, 113]
# keypoints for octave 1 [1, 114]
# keypoints for octave 1 [1, 115]
# keypoints for octave 1 [1, 116]
# keypoints for octave 1 [1, 117]
# keypoints for octave 1 [1, 118]
# keypoints for octave 1 [1, 119]
# keypoints for octave 1 [1, 120]
# keypoints for octave 1 [1, 121]
# keypoints for octave 1 [1, 122]
# keypoints for octave 1 [1, 123]
# keypoints for octave 1 [1, 124]
# keypoints for octave 1 [1, 125]
# keypoints for octave 1 [1, 126]
# keypoints for octave 1 [1, 127]
# keypoints for octave 1 [1, 128]
# keypoints for octave 1 [1, 129]
# keypoints for octave 1 [1, 130]
# keypoints for octave 1 [1, 131]
# keypoints for octave 1 [1, 132]
# keypoints for octave 1 [1, 133]
# keypoints for octave 1 [1, 134]
# keypoints for octave 1 [1, 135]
# keypoints for octave 1 [1, 136]
# keypoints for octave 1 [1, 137]
# keypoints for octave 1 [1, 138]
# keypoints for octave 1 [1, 139]
# keypoints for octave 1 [1, 140]
# keypoints for octave 1 [1, 141]
# keypoints for octave 1 [1, 142]
# keypoints for octave 1 [1, 143]
# keypoints for octave 1 [1, 144]
# keypoints for octave 1 [1, 145]
# keypoints for octave 1 [1, 146]
# keypoints for octave 1 [1, 147]
# keypoints for octave 1 [1, 148]
# keypoints for octave 1 [1, 149]
# keypoints for octave 1 [1, 150]
# keypoints for octave 1 [1, 151]
# keypoints for octave 1 [1, 152]
# keypoints for octave 1 [1, 153]
# keypoints for octave 1 [1, 154]
# keypoints for octave 1 [1, 155]
# keypoints for octave 1 [1, 156]
# keypoints for octave 1 [1, 157]
# keypoints for octave 1 [1, 158]
# keypoints for octave 1 [1, 159]
# keypoints for octave 1 [1, 160]
# keypoints for octave 1 [1, 161]
# keypoints for octave 1 [1, 162]
# keypoints for octave 1 [1, 163]
# keypoints for octave 1 [1, 164]
# keypoints for octave 1 [1, 165]
# keypoints for octave 1 [1, 166]
# keypoints for octave 1 [1, 167]
# keypoints for octave 1 [1, 168]
# keypoints for octave 1 [1, 169]
# keypoints for octave 1 [1, 170]
# keypoints for octave 1 [1, 171]
# keypoints for octave 1 [1, 172]
# keypoints for octave 1 [1, 173]
# keypoints for octave 1 [1, 174]
# keypoints for octave 1 [1, 175]
# keypoints for octave 1 [1, 176]
# keypoints for octave 1 [1, 177]
# keypoints for octave 1 [1, 178]
# keypoints for octave 1 [1, 179]
# keypoints for octave 1 [1, 180]
# keypoints for octave 1 [1, 181]
# keypoints for octave 1 [1, 182]
# keypoints for octave 1 [1, 183]
# keypoints for octave 1 [1, 184]
# keypoints for octave 1 [1, 185]
# keypoints for octave 1 [1, 186]
# keypoints for octave 1 [1, 187]
# keypoints for octave 1 [1, 188]
# keypoints for octave 1 [1, 189]
# keypoints for octave 1 [1, 190]
# keypoints for octave 1 [1, 191]
# keypoints for octave 1 [1, 192]
# keypoints for octave 1 [1, 193]
# keypoints for octave 1 [1, 194]
# keypoints for octave 1 [1, 195]
# keypoints for octave 1 [1, 196]
# keypoints for octave 1 [1, 197]
# keypoints for octave 1 [1, 198]
# keypoints for octave 1 [1, 199]
# keypoints for octave 1 [1, 200]
# keypoints for octave 1 [1, 201]
# keypoints for octave 1 [1, 202]
# keypoints for octave 1 [1, 203]
# keypoints for octave 1 [1, 204]
# keypoints for octave 1 [1, 205]
# keypoints for octave 1 [1, 206]
# keypoints for octave 1 [1, 207]
# keypoints for octave 1 [1, 208]
# keypoints for octave 1 [1, 209]
# keypoints for octave 1 [1, 210]
# keypoints for octave 1 [1, 211]
# keypoints for octave 1 [1, 212]
# keypoints for octave 1 [1, 213]
# keypoints for octave 1 [1, 214]
# keypoints for octave 1 [1, 215]
# keypoints for octave 1 [1, 216]
# keypoints for octave 1 [1, 217]
# keypoints for octave 1 [1, 218]
# keypoints for octave 1 [1, 219]
# keypoints for octave 1 [1, 220]
# keypoints for octave 1 [1, 221]
# keypoints for octave 1 [1, 222]
# keypoints for octave 1 [1, 223]
# keypoints for octave 1 [1, 224]
# keypoints for octave 1 [1, 225]
# keypoints for octave 1 [1, 226]
# keypoints for octave 1 [1, 227]
# keypoints for octave 1 [1, 228]
# keypoints for octave 1 [1, 229]
# keypoints for octave 1 [1, 230]
# keypoints for octave 1 [1, 231]
# keypoints for octave 1 [1, 232]
# keypoints for octave 1 [1, 233]
# keypoints for octave 1 [1, 234]
# keypoints for octave 1 [1, 235]
# keypoints for octave 1 [1, 236]
# keypoints for octave 1 [1, 237]
# keypoints for octave 1 [1, 238]
# keypoints for octave 1 [1, 239]
# keypoints for octave 1 [1, 240]
# keypoints for octave 1 [1, 241]
# keypoints for octave 1 [1, 242]
# keypoints for octave 1 [1, 243]
# keypoints for octave 1 [1, 244]
# keypoints for octave 1 [1, 245]
# keypoints for octave 1 [1, 246]
# keypoints for octave 1 [1, 247]
# keypoints for octave 1 [1, 248]
# keypoints for octave 1 [1, 249]
# keypoints for octave 1 [1, 250]
# keypoints for octave 1 [1, 251]
# keypoints for octave 1 [1, 252]
# keypoints for octave 1 [1, 253]
# keypoints for octave 1 [1, 254]
# keypoints for octave 1 [1, 255]
# keypoints for octave 1 [1, 256]
# keypoints for octave 1 [1, 257]
# keypoints for octave 1 [1, 258]
# keypoints for octave 1 [1, 259]
# keypoints for octave 1 [1, 260]
# keypoints for octave 1 [1, 261]
# keypoints for octave 1 [1, 262]
# keypoints for octave 1 [1, 263]
# keypoints for octave 1 [1, 264]
# keypoints for octave 1 [1, 265]
# keypoints for octave 1 [1, 266]
# keypoints for octave 1 [1, 267]
# keypoints for octave 1 [1, 268]
# keypoints for octave 1 [1, 269]
# keypoints for octave 1 [1, 270]
# keypoints for octave 1 [1, 271]
# keypoints for octave 1 [1, 272]
# keypoints for octave 1 [1, 273]
# keypoints for octave 1 [1, 274]
# keypoints for octave 1 [1, 275]
# keypoints for octave 1 [1, 276]
# keypoints for octave 1 [1, 277]
# keypoints for octave 1 [1, 278]
# keypoints for octave 1 [1, 279]
# keypoints for octave 1 [1, 280]
# keypoints for octave 1 [1, 281]
# keypoints for octave 1 [1, 282]
# keypoints for octave 1 [1, 283]
# keypoints for octave 1 [1, 284]
# keypoints for octave 1 [1, 285]
# keypoints for octave 1 [1, 286]
# keypoints for octave 1 [1, 287]
# keypoints for octave 1 [1, 288]
# keypoints for octave 1 [1, 289]
# keypoints for octave 1 [1, 290]
# keypoints for octave 1 [1, 291]
# keypoints for octave 1 [1, 292]
# keypoints for octave 1 [1, 293]
# keypoints for octave 1 [1, 294]
# keypoints for octave 1 [1, 295]
# keypoints for octave 1 [1, 296]
# keypoints for octave 1 [1, 297]
# keypoints for octave 1 [1, 298]
# keypoints for octave 1 [1, 299]
# keypoints for octave 1 [1, 300]
# keypoints for octave 1 [1, 301]
# keypoints for octave 1 [1, 302]
# keypoints for octave 1 [1, 303]
# keypoints for octave 1 [1, 304]
# keypoints for octave 1 [1, 305]
# keypoints for octave 1 [1, 306]
# keypoints for octave 1 [1, 307]
# keypoints for octave 1 [1, 308]
# keypoints for octave 1 [1, 309]
# keypoints for octave 1 [1, 310]
# keypoints for octave 1 [1, 311]
# keypoints for octave 1 [1, 312]
# keypoints for octave 1 [1, 313]
# keypoints for octave 1 [1, 314]
# keypoints for octave 1 [1, 315]
# keypoints for octave 1 [1, 316]
# keypoints for octave 1 [1, 317]
# keypoints for octave 1 [1, 318]
# keypoints for octave 1 [1, 319]
# keypoints for octave 1 [1, 320]
# keypoints for octave 1 [1, 321]
# keypoints for octave 1 [1, 322]
# keypoints for octave 1 [1, 323]
# keypoints for octave 1 [1, 324]
# keypoints for octave 1 [1, 325]
# keypoints for octave 1 [1, 326]
# keypoints for octave 1 [1, 327]
# keypoints for octave 1 [1, 328]
# keypoints for octave 1 [1, 329]
# keypoints for octave 1 [1, 330]
# keypoints for octave 1 [1, 331]
# keypoints for octave 1 [1, 332]
# keypoints for octave 1 [1, 333]
# keypoints for octave 1 [1, 334]
# keypoints for octave 1 [1, 335]
# keypoints for octave 1 [1, 336]
# keypoints for octave 1 [1, 337]
# keypoints for octave 1 [1, 338]
# keypoints for octave 1 [1, 339]
# keypoints for octave 1 [1, 340]
# keypoints for octave 1 [1, 341]
# keypoints for octave 1 [1, 342]
# keypoints for octave 1 [1, 343]
# keypoints for octave 1 [1, 344]
# keypoints for octave 1 [1, 345]
# keypoints for octave 1 [1, 346]
# keypoints for octave 1 [1, 347]
# keypoints for octave 1 [1, 348]
# keypoints for octave 1 [1, 349]
# keypoints for octave 1 [1, 350]
# keypoints for octave 1 [1, 351]
# keypoints for octave 1 [1, 352]
# keypoints for octave 1 [1, 353]
# keypoints for octave 1 [1, 354]
# keypoints for octave 1 [1, 355]
# keypoints for octave 1 [1, 356]
# keypoints for octave 1 [1, 357]
# keypoints for octave 1 [1, 358]
# keypoints for octave 1 [1, 359]
# keypoints for octave 1 [1, 360]
# keypoints for octave 1 [1, 361]
# keypoints for octave 1 [1, 362]
# keypoints for octave 1 [1, 363]
# keypoints for octave 1 [1, 364]
# keypoints for octave 1 [1, 365]
# keypoints for octave 1 [1, 366]
# keypoints for octave 1 [1, 367]
# keypoints for octave 1 [1, 368]
# keypoints for octave 1 [1, 369]
# keypoints for octave 1 [1, 370]
# keypoints for octave 1 [1, 371]
# keypoints for octave 1 [1, 372]
# keypoints for octave 1 [1, 373]
# keypoints for octave 1 [1, 374]
# keypoints for octave 1 [1, 375]
# keypoints for octave 1 [1, 376]
# keypoints for octave 1 [1, 377]
# keypoints for octave 1 [1, 378]
# keypoints for octave 1 [1, 379]
# keypoints for octave 1 [1, 380]
# keypoints for octave 1 [1, 381]
# keypoints for octave 1 [1, 382]
# keypoints for octave 1 [1, 383]
# keypoints for octave 1 [1, 384]
# keypoints for octave 1 [1, 385]
# keypoints for octave 1 [1, 386]
# keypoints for octave 1 [1, 387]
# keypoints for octave 1 [1, 388]
# keypoints for octave 1 [1, 389]
# keypoints for octave 1 [1, 390]
# keypoints for octave 1 [1, 391]
# keypoints for octave 1 [1, 392]
# keypoints for octave 1 [1, 393]
# keypoints for octave 1 [1, 394]
# keypoints for octave 1 [1, 395]
# keypoints for octave 1 [1, 396]
# keypoints for octave 1 [1, 397]
# keypoints for octave 1 [1, 398]
# keypoints for octave 1 [1, 399]
# keypoints for octave 1 [1, 400]
# keypoints for octave 1 [1, 401]
# keypoints for octave 1 [1, 402]
# keypoints for octave 1 [1, 403]
# keypoints for octave 1 [1, 404]
# keypoints for octave 1 [1, 405]
# keypoints for octave 1 [1, 406]
# keypoints for octave 1 [1, 407]
# keypoints for octave 1 [1, 408]
# keypoints for octave 1 [1, 409]
# keypoints for octave 1 [1, 410]
# keypoints for octave 1 [1, 411]
# keypoints for octave 1 [1, 412]
# keypoints for octave 1 [1, 413]
# keypoints for octave 1 [1, 414]
# keypoints for octave 1 [1, 415]
# keypoints for octave 1 [1, 416]
# keypoints for octave 1 [1, 417]
# keypoints for octave 1 [1, 418]
# keypoints for octave 1 [1, 419]
# keypoints for octave 1 [1, 420]
# keypoints for octave 1 [1, 421]
# keypoints for octave 1 [1, 422]
# keypoints for octave 1 [1, 423]
# keypoints for octave 1 [1, 424]
# keypoints for octave 1 [1, 425]
# keypoints for octave 1 [1, 426]
# keypoints for octave 1 [1, 427]
# keypoints for octave 1 [1, 428]
# keypoints for octave 1 [1, 429]
# keypoints for octave 1 [1, 430]
# keypoints for octave 1 [1, 431]
# keypoints for octave 1 [1, 432]
# keypoints for octave 1 [1, 433]
# keypoints for octave 1 [1, 434]
# keypoints for octave 1 [1, 435]
# keypoints for octave 1 [1, 436]
# keypoints for octave 1 [1, 437]
# keypoints for octave 1 [1, 438]
# keypoints for octave 1 [1, 439]
# keypoints for octave 1 [1, 440]
# keypoints for octave 1 [1, 441]
# keypoints for octave 1 [1, 442]
# keypoints for octave 1 [1, 443]
# keypoints for octave 1 [1, 444]
# keypoints for octave 1 [1, 445]
# keypoints for octave 1 [1, 446]
# keypoints for octave 1 [1, 447]
# keypoints for octave 1 [1, 448]
# keypoints for octave 1 [1, 449]
# keypoints for octave 1 [1, 450]
# keypoints for octave 1 [1, 451]
# keypoints for octave 1 [1, 452]
# keypoints for octave 1 [1, 453]
# keypoints for octave 1 [1, 454]
# keypoints for octave 1 [1, 455]
# keypoints for octave 1 [1, 456]
# keypoints for octave 1 [1, 457]
# keypoints for octave 1 [1, 458]
# keypoints for octave 1 [1, 459]
# keypoints for octave 1 [1, 460]
# keypoints for octave 1 [1, 461]
# keypoints for octave 1 [1, 462]
# keypoints for octave 1 [1, 463]
# keypoints for octave 1 [1, 464]
# keypoints for octave 1 [1, 465]
# keypoints for octave 1 [1, 466]
# keypoints for octave 1 [1, 467]
# keypoints for octave 1 [1, 468]
# keypoints for octave 1 [1, 469]
# keypoints for octave 1 [1, 470]
# keypoints for octave 1 [1, 471]
# keypoints for octave 1 [1, 472]
# keypoints for octave 1 [1, 473]
# keypoints for octave 1 [1, 474]
# keypoints for octave 1 [1, 475]
# keypoints for octave 1 [1, 476]
# keypoints for octave 1 [1, 477]
# keypoints for octave 1 [1, 478]
# keypoints for octave 1 [1, 479]
# keypoints for octave 1 [1, 480]
# keypoints for octave 1 [1, 481]
# keypoints for octave 1 [1, 482]
# keypoints for octave 1 [1, 483]
# keypoints for octave 1 [1, 484]
# keypoints for octave 1 [1, 485]
# keypoints for octave 1 [1, 486]
# keypoints for octave 1 [1, 487]
# keypoints for octave 1 [1, 488]
# keypoints for octave 1 [1, 489]
# keypoints for octave 1 [1, 490]
# keypoints for octave 1 [1, 491]
# keypoints for octave 1 [1, 492]
# keypoints for octave 1 [1, 493]
# keypoints for octave 1 [1, 494]
# keypoints for octave 1 [1, 495]
# keypoints for octave 1 [1, 496]
# keypoints for octave 1 [1, 497]
# keypoints for octave 1 [1, 498]
# keypoints for octave 1 [1, 499]
# keypoints for octave 1 [1, 500]
# keypoints for octave 1 [1, 501]
# keypoints for octave 1 [1, 502]
# keypoints for octave 1 [1, 503]
# keypoints for octave 1 [1, 504]
# keypoints for octave 1 [1, 505]
# keypoints for octave 1 [1, 506]
# keypoints for octave 1 [1, 507]
# keypoints for octave 1 [1, 508]
# keypoints for octave 1 [1, 509]
# keypoints for octave 1 [1, 510]
# keypoints for octave 1 [1, 511]
# keypoints for octave 1 [1, 512]
# keypoints for octave 1 [1, 513]
# keypoints for octave 1 [1, 514]
# keypoints for octave 1 [1, 515]
# keypoints for octave 1 [1, 516]
# keypoints for octave 1 [1, 517]
# keypoints for octave 1 [1, 518]
# keypoints for octave 1 [1, 519]
# keypoints for octave 1 [1, 520]
# keypoints for octave 1 [1, 521]
# keypoints for octave 1 [1, 522]
# keypoints for octave 1 [1, 523]
# keypoints for octave 1 [1, 524]
# keypoints for octave 1 [1, 525]
# keypoints for octave 1 [1, 526]
# keypoints for octave 1 [1, 527]
# keypoints for octave 1 [1, 528]
# keypoints for octave 1 [1, 529]
# keypoints for octave 1 [1, 530]
# keypoints for octave 1 [1, 531]
# keypoints for octave 1 [1, 532]
# keypoints for octave 1 [1, 533]
# keypoints for octave 1 [1, 534]
# keypoints for octave 1 [1, 535]
# keypoints for octave 1 [1, 536]
# keypoints for octave 1 [1, 537]
# keypoints for octave 1 [1, 538]
# keypoints for octave 1 [1, 539]
# keypoints for octave 1 [1, 540]
# keypoints for octave 1 [1, 541]
# keypoints for octave 1 [1, 542]
# keypoints for octave 1 [1, 543]
# keypoints for octave 1 [1, 544]
# keypoints for octave 1 [1, 545]
# keypoints for octave 1 [1, 546]
# keypoints for octave 1 [1, 547]
# keypoints for octave 1 [1, 548]
# keypoints for octave 1 [1, 549]
# keypoints for octave 1 [1, 550]
# keypoints for octave 1 [1, 551]
# keypoints for octave 1 [1, 552]
# keypoints for octave 1 [1, 553]
# keypoints for octave 1 [1, 554]
# keypoints for octave 1 [1, 555]
# keypoints for octave 1 [1, 556]
# keypoints for octave 1 [1, 557]
# keypoints for octave 1 [1, 558]
# keypoints for octave 1 [1, 559]
# keypoints for octave 1 [1, 560]
# keypoints for octave 1 [1, 561]
# keypoints for octave 1 [1, 562]
# keypoints for octave 1 [1, 563]
# keypoints for octave 1 [1, 564]
# keypoints for octave 1 [1, 565]
# keypoints for octave 1 [1, 566]
# keypoints for octave 1 [1, 567]
# keypoints for octave 1 [1, 568]
# keypoints for octave 1 [1, 569]
# keypoints for octave 1 [1, 570]
# keypoints for octave 1 [1, 571]
# keypoints for octave 1 [1, 572]
# keypoints for octave 1 [1, 573]
# keypoints for octave 1 [1, 574]
# keypoints for octave 1 [1, 575]
# keypoints for octave 1 [1, 576]
# keypoints for octave 1 [1, 577]
# keypoints for octave 1 [1, 578]
# keypoints for octave 1 [1, 579]
# keypoints for octave 1 [1, 580]
# keypoints for octave 1 [1, 581]
# keypoints for octave 1 [1, 582]
# keypoints for octave 1 [1, 583]
# keypoints for octave 1 [1, 584]
# keypoints for octave 1 [1, 585]
# keypoints for octave 1 [1, 586]
# keypoints for octave 1 [1, 587]
# keypoints for octave 1 [1, 588]
# keypoints for octave 1 [1, 589]
# keypoints for octave 1 [1, 590]
# keypoints for octave 1 [1, 591]
# keypoints for octave 1 [1, 592]
# keypoints for octave 1 [1, 593]
# keypoints for octave 1 [1, 594]
# keypoints for octave 1 [1, 595]
# keypoints for octave 1 [1, 596]
# keypoints for octave 1 [1, 597]
# keypoints for octave 1 [1, 598]
# keypoints for octave 1 [1, 599]
# keypoints for octave 1 [1, 600]
# keypoints for octave 1 [1, 601]
# keypoints for octave 1 [1, 602]
# keypoints for octave 1 [1, 603]
# keypoints for octave 1 [1, 604]
# keypoints for octave 1 [1, 605]
# keypoints for octave 1 [1, 606]
# keypoints for octave 1 [1, 607]
# keypoints for octave 1 [1, 608]
# keypoints for octave 1 [1, 609]
# keypoints for octave 1 [1, 610]
# keypoints for octave 1 [1, 611]
# keypoints for octave 1 [1, 612]
# keypoints for octave 1 [1, 613]
# keypoints for octave 1 [1, 614]
# keypoints for octave 1 [1, 615]
# keypoints for octave 1 [1, 616]
# keypoints for octave 1 [1, 617]
# keypoints for octave 1 [1, 618]
# keypoints for octave 1 [1, 619]
# keypoints for octave 1 [1, 620]
# keypoints for octave 1 [1, 621]
# keypoints for octave 1 [1, 622]
# keypoints for octave 1 [1, 623]
# keypoints for octave 1 [1, 624]
# keypoints for octave 1 [1, 625]
# keypoints for octave 1 [1, 626]
# keypoints for octave 1 [1, 627]
# keypoints for octave 1 [1, 628]
# keypoints for octave 1 [1, 629]
# keypoints for octave 1 [1, 630]
# keypoints for octave 1 [1, 631]
# keypoints for octave 1 [1, 632]
# keypoints for octave 1 [1, 633]
# keypoints for octave 1 [1, 634]
# keypoints for octave 1 [1, 635]
# keypoints for octave 1 [1, 636]
# keypoints for octave 1 [1, 637]
# keypoints for octave 1 [1, 638]
# keypoints for octave 1 [1, 639]
# keypoints for octave 1 [1, 640]
# keypoints for octave 1 [1, 641]
# keypoints for octave 1 [1, 642]
# keypoints for octave 1 [1, 643]
# keypoints for octave 1 [1, 644]
# keypoints for octave 1 [1, 645]
# keypoints for octave 1 [1, 646]
# keypoints for octave 1 [1, 647]
# keypoints for octave 1 [1, 648]
# keypoints for octave 1 [1, 649]
# keypoints for octave 1 [1, 650]
# keypoints for octave 1 [1, 651]
# keypoints for octave 1 [1, 652]
# keypoints for octave 1 [1, 653]
# keypoints for octave 1 [1, 654]
# keypoints for octave 1 [1, 655]
# keypoints for octave 1 [1, 656]
# keypoints for octave 1 [1, 657]
# keypoints for octave 1 [1, 658]
# keypoints for octave 1 [1, 659]
# keypoints for octave 1 [1, 660]
# keypoints for octave 1 [1, 661]
# keypoints for octave 1 [1, 662]
# keypoints for octave 1 [1, 663]
# keypoints for octave 1 [1, 664]
# keypoints for octave 1 [1, 665]
# keypoints for octave 1 [1, 666]
# keypoints for octave 1 [1, 667]
# keypoints for octave 1 [1, 668]
# keypoints for octave 1 [1, 669]
# keypoints for octave 1 [1, 670]
# keypoints for octave 1 [1, 671]
# keypoints for octave 1 [1, 672]
# keypoints for octave 1 [1, 673]
# keypoints for octave 1 [1, 674]
# keypoints for octave 1 [1, 675]
# keypoints for octave 1 [1, 676]
# keypoints for octave 1 [1, 677]
# keypoints for octave 1 [1, 678]
# keypoints for octave 1 [1, 679]
# keypoints for octave 1 [1, 680]
# keypoints for octave 1 [1, 681]
# keypoints for octave 1 [1, 682]
# keypoints for octave 1 [1, 683]
# keypoints for octave 1 [1, 684]
# keypoints for octave 1 [1, 685]
# keypoints for octave 1 [1, 686]
# keypoints for octave 1 [1, 687]
# keypoints for octave 1 [1, 688]
# keypoints for octave 1 [1, 689]
# keypoints for octave 1 [1, 690]
# keypoints for octave 1 [1, 691]
# keypoints for octave 1 [1, 692]
# keypoints for octave 1 [1, 693]
# keypoints for octave 1 [1, 694]
# keypoints for octave 1 [1, 695]
# keypoints for octave 1 [1, 696]
# keypoints for octave 1 [1, 697]
# keypoints for octave 1 [1, 698]
# keypoints for octave 1 [1, 699]
# keypoints for octave 1 [1, 700]
# keypoints for octave 1 [1, 701]
# keypoints for octave 1 [1, 702]
# keypoints for octave 1 [1, 703]
# keypoints for octave 1 [1, 704]
# keypoints for octave 1 [1, 705]
# keypoints for octave 1 [1, 706]
# keypoints for octave 1 [1, 707]
# keypoints for octave 1 [1, 708]
# keypoints for octave 1 [1, 709]
# keypoints for octave 1 [1, 710]
# keypoints for octave 1 [1, 711]
# keypoints for octave 1 [1, 712]
# keypoints for octave 1 [1, 713]
# keypoints for octave 1 [1, 714]
# keypoints for octave 1 [1, 715]
# keypoints for octave 1 [1, 716]
# keypoints for octave 1 [1, 717]
# keypoints for octave 1 [1, 718]
# keypoints for octave 1 [1, 719]
# keypoints for octave 1 [1, 720]
# keypoints for octave 1 [1, 721]
# keypoints for octave 1 [1, 722]
# keypoints for octave 1 [1, 723]
# keypoints for octave 1 [1, 724]
# keypoints for octave 1 [1, 725]
# keypoints for octave 1 [1, 726]
# keypoints for octave 1 [1, 727]
# keypoints for octave 1 [1, 728]
# keypoints for octave 1 [1, 729]
# keypoints for octave 1 [1, 730]
# keypoints for octave 1 [1, 731]
# keypoints for octave 1 [1, 732]
# keypoints for octave 1 [1, 733]
# keypoints for octave 1 [1, 734]
# keypoints for octave 1 [1, 735]
# keypoints for octave 1 [1, 736]
# keypoints for octave 1 [1, 737]
# keypoints for octave 1 [1, 738]
# keypoints for octave 1 [1, 739]
# keypoints for octave 1 [1, 740]
# keypoints for octave 1 [1, 741]
# keypoints for octave 1 [1, 742]
# keypoints for octave 1 [1, 743]
# keypoints for octave 1 [1, 744]
# keypoints for octave 1 [1, 745]
# keypoints for octave 1 [1, 746]
# keypoints for octave 1 [1, 747]
# keypoints for octave 1 [1, 748]
# keypoints for octave 1 [2, 1]
# keypoints for octave 1 [2, 2]
# keypoints for octave 1 [2, 3]
# keypoints for octave 1 [2, 4]
# keypoints for octave 1 [2, 5]
# keypoints for octave 1 [2, 6]
# keypoints for octave 1 [2, 7]
# keypoints for octave 1 [2, 8]
# keypoints for octave 1 [2, 9]
# keypoints for octave 1 [2, 10]
# keypoints for octave 1 [2, 11]
# keypoints for octave 1 [2, 12]
# keypoints for octave 1 [2, 13]
# keypoints for octave 1 [2, 14]
# keypoints for octave 1 [2, 15]
# keypoints for octave 1 [2, 16]
# keypoints for octave 1 [2, 17]
# keypoints for octave 1 [2, 18]
# keypoints for octave 1 [2, 19]
# keypoints for octave 1 [2, 20]
# keypoints for octave 1 [2, 21]
# keypoints for octave 1 [2, 22]
# keypoints for octave 1 [2, 23]
# keypoints for octave 1 [2, 24]
# keypoints for octave 1 [2, 25]
# keypoints for octave 1 [2, 26]
# keypoints for octave 1 [2, 27]
# keypoints for octave 1 [2, 28]
# keypoints for octave 1 [2, 32]
# keypoints for octave 1 [2, 33]
# keypoints for octave 1 [2, 34]
# keypoints for octave 1 [2, 35]
# keypoints for octave 1 [2, 40]
# keypoints for octave 1 [2, 41]
# keypoints for octave 1 [2, 42]
# keypoints for octave 1 [2, 43]
# keypoints for octave 1 [2, 44]
# keypoints for octave 1 [2, 45]
# keypoints for octave 1 [2, 46]
# keypoints for octave 1 [2, 47]
# keypoints for octave 1 [2, 48]
# keypoints for octave 1 [2, 49]
# keypoints for octave 1 [2, 50]
# keypoints for octave 1 [2, 56]
# keypoints for octave 1 [2, 57]
# keypoints for octave 1 [2, 58]
# keypoints for octave 1 [2, 59]
# keypoints for octave 1 [2, 60]
# keypoints for octave 1 [2, 61]
# keypoints for octave 1 [2, 62]
# keypoints for octave 1 [2, 63]
# keypoints for octave 1 [2, 64]
# keypoints for octave 1 [2, 65]
# keypoints for octave 1 [2, 66]
# keypoints for octave 1 [2, 69]
# keypoints for octave 1 [2, 70]
# keypoints for octave 1 [2, 71]
# keypoints for octave 1 [2, 74]
# keypoints for octave 1 [2, 75]
# keypoints for octave 1 [2, 76]
# keypoints for octave 1 [2, 77]
# keypoints for octave 1 [2, 78]
# keypoints for octave 1 [2, 79]
# keypoints for octave 1 [2, 80]
# keypoints for octave 1 [2, 81]
# keypoints for octave 1 [2, 82]
# keypoints for octave 1 [2, 83]
# keypoints for octave 1 [2, 84]
# keypoints for octave 1 [2, 85]
# keypoints for octave 1 [2, 88]
# keypoints for octave 1 [2, 89]
# keypoints for octave 1 [2, 90]
# keypoints for octave 1 [2, 91]
# keypoints for octave 1 [2, 96]
# keypoints for octave 1 [2, 97]
# keypoints for octave 1 [2, 98]
# keypoints for octave 1 [2, 100]
# keypoints for octave 1 [2, 101]
# keypoints for octave 1 [2, 102]
# keypoints for octave 1 [2, 110]
# keypoints for octave 1 [2, 111]
# keypoints for octave 1 [2, 112]
# keypoints for octave 1 [2, 117]
# keypoints for octave 1 [2, 118]
# keypoints for octave 1 [2, 119]
# keypoints for octave 1 [2, 133]
# keypoints for octave 1 [2, 134]
# keypoints for octave 1 [2, 135]
# keypoints for octave 1 [2, 136]
# keypoints for octave 1 [2, 137]
# keypoints for octave 1 [2, 138]
# keypoints for octave 1 [2, 139]
# keypoints for octave 1 [2, 140]
# keypoints for octave 1 [2, 145]
# keypoints for octave 1 [2, 146]
# keypoints for octave 1 [2, 147]
# keypoints for octave 1 [2, 148]
# keypoints for octave 1 [2, 149]
# keypoints for octave 1 [2, 150]
# keypoints for octave 1 [2, 151]
# keypoints for octave 1 [2, 152]
# keypoints for octave 1 [2, 153]
# keypoints for octave 1 [2, 154]
# keypoints for octave 1 [2, 155]
# keypoints for octave 1 [2, 156]
# keypoints for octave 1 [2, 157]
# keypoints for octave 1 [2, 158]
# keypoints for octave 1 [2, 159]
# keypoints for octave 1 [2, 160]
# keypoints for octave 1 [2, 161]
# keypoints for octave 1 [2, 166]
# keypoints for octave 1 [2, 167]
# keypoints for octave 1 [2, 168]
# keypoints for octave 1 [2, 169]
# keypoints for octave 1 [2, 170]
# keypoints for octave 1 [2, 171]
# keypoints for octave 1 [2, 172]
# keypoints for octave 1 [2, 173]
# keypoints for octave 1 [2, 174]
# keypoints for octave 1 [2, 175]
# keypoints for octave 1 [2, 176]
# keypoints for octave 1 [2, 179]
# keypoints for octave 1 [2, 180]
# keypoints for octave 1 [2, 181]
# keypoints for octave 1 [2, 182]
# keypoints for octave 1 [2, 184]
# keypoints for octave 1 [2, 185]
# keypoints for octave 1 [2, 186]
# keypoints for octave 1 [2, 187]
# keypoints for octave 1 [2, 188]
# keypoints for octave 1 [2, 189]
# keypoints for octave 1 [2, 190]
# keypoints for octave 1 [2, 191]
# keypoints for octave 1 [2, 192]
# keypoints for octave 1 [2, 199]
# keypoints for octave 1 [2, 200]
# keypoints for octave 1 [2, 201]
# keypoints for octave 1 [2, 202]
# keypoints for octave 1 [2, 203]
# keypoints for octave 1 [2, 204]
# keypoints for octave 1 [2, 205]
# keypoints for octave 1 [2, 206]
# keypoints for octave 1 [2, 212]
# keypoints for octave 1 [2, 213]
# keypoints for octave 1 [2, 214]
# keypoints for octave 1 [2, 215]
# keypoints for octave 1 [2, 216]
# keypoints for octave 1 [2, 217]
# keypoints for octave 1 [2, 218]
# keypoints for octave 1 [2, 219]
# keypoints for octave 1 [2, 223]
# keypoints for octave 1 [2, 224]
# keypoints for octave 1 [2, 225]
# keypoints for octave 1 [2, 226]
# keypoints for octave 1 [2, 227]
# keypoints for octave 1 [2, 228]
# keypoints for octave 1 [2, 232]
# keypoints for octave 1 [2, 233]
# keypoints for octave 1 [2, 234]
# keypoints for octave 1 [2, 235]
# keypoints for octave 1 [2, 236]
# keypoints for octave 1 [2, 237]
# keypoints for octave 1 [2, 238]
# keypoints for octave 1 [2, 239]
# keypoints for octave 1 [2, 240]
# keypoints for octave 1 [2, 241]
# keypoints for octave 1 [2, 242]
# keypoints for octave 1 [2, 243]
# keypoints for octave 1 [2, 244]
# keypoints for octave 1 [2, 245]
# keypoints for octave 1 [2, 250]
# keypoints for octave 1 [2, 251]
# keypoints for octave 1 [2, 252]
# keypoints for octave 1 [2, 253]
# keypoints for octave 1 [2, 254]
# keypoints for octave 1 [2, 255]
# keypoints for octave 1 [2, 256]
# keypoints for octave 1 [2, 257]
# keypoints for octave 1 [2, 258]
# keypoints for octave 1 [2, 259]
# keypoints for octave 1 [2, 260]
# keypoints for octave 1 [2, 261]
# keypoints for octave 1 [2, 262]
# keypoints for octave 1 [2, 263]
# keypoints for octave 1 [2, 264]
# keypoints for octave 1 [2, 265]
# keypoints for octave 1 [2, 266]
# keypoints for octave 1 [2, 272]
# keypoints for octave 1 [2, 273]
# keypoints for octave 1 [2, 274]
# keypoints for octave 1 [2, 277]
# keypoints for octave 1 [2, 278]
# keypoints for octave 1 [2, 279]
# keypoints for octave 1 [2, 280]
# keypoints for octave 1 [2, 281]
# keypoints for octave 1 [2, 288]
# keypoints for octave 1 [2, 289]
# keypoints for octave 1 [2, 290]
# keypoints for octave 1 [2, 291]
# keypoints for octave 1 [2, 292]
# keypoints for octave 1 [2, 293]
# keypoints for octave 1 [2, 294]
# keypoints for octave 1 [2, 295]
# keypoints for octave 1 [2, 296]
# keypoints for octave 1 [2, 297]
# keypoints for octave 1 [2, 298]
# keypoints for octave 1 [2, 299]
# keypoints for octave 1 [2, 302]
# keypoints for octave 1 [2, 303]
# keypoints for octave 1 [2, 304]
# keypoints for octave 1 [2, 305]
# keypoints for octave 1 [2, 306]
# keypoints for octave 1 [2, 307]
# keypoints for octave 1 [2, 308]
# keypoints for octave 1 [2, 309]
# keypoints for octave 1 [2, 311]
# keypoints for octave 1 [2, 312]
# keypoints for octave 1 [2, 313]
# keypoints for octave 1 [2, 314]
# keypoints for octave 1 [2, 315]
# keypoints for octave 1 [2, 316]
# keypoints for octave 1 [2, 317]
# keypoints for octave 1 [2, 318]
# keypoints for octave 1 [2, 319]
# keypoints for octave 1 [2, 324]
# keypoints for octave 1 [2, 325]
# keypoints for octave 1 [2, 326]
# keypoints for octave 1 [2, 328]
# keypoints for octave 1 [2, 329]
# keypoints for octave 1 [2, 330]
# keypoints for octave 1 [2, 331]
# keypoints for octave 1 [2, 332]
# keypoints for octave 1 [2, 333]
# keypoints for octave 1 [2, 334]
# keypoints for octave 1 [2, 335]
# keypoints for octave 1 [2, 337]
# keypoints for octave 1 [2, 338]
# keypoints for octave 1 [2, 339]
# keypoints for octave 1 [2, 340]
# keypoints for octave 1 [2, 341]
# keypoints for octave 1 [2, 349]
# keypoints for octave 1 [2, 350]
# keypoints for octave 1 [2, 351]
# keypoints for octave 1 [2, 353]
# keypoints for octave 1 [2, 354]
# keypoints for octave 1 [2, 355]
# keypoints for octave 1 [2, 356]
# keypoints for octave 1 [2, 357]
# keypoints for octave 1 [2, 358]
# keypoints for octave 1 [2, 359]
# keypoints for octave 1 [2, 360]
# keypoints for octave 1 [2, 361]
# keypoints for octave 1 [2, 363]
# keypoints for octave 1 [2, 364]
# keypoints for octave 1 [2, 365]
# keypoints for octave 1 [2, 366]
# keypoints for octave 1 [2, 367]
# keypoints for octave 1 [2, 390]
# keypoints for octave 1 [2, 391]
# keypoints for octave 1 [2, 392]
# keypoints for octave 1 [2, 396]
# keypoints for octave 1 [2, 397]
# keypoints for octave 1 [2, 398]
# keypoints for octave 1 [2, 399]
# keypoints for octave 1 [2, 408]
# keypoints for octave 1 [2, 409]
# keypoints for octave 1 [2, 410]
# keypoints for octave 1 [2, 419]
# keypoints for octave 1 [2, 420]
# keypoints for octave 1 [2, 421]
# keypoints for octave 1 [2, 422]
# keypoints for octave 1 [2, 428]
# keypoints for octave 1 [2, 429]
# keypoints for octave 1 [2, 430]
# keypoints for octave 1 [2, 433]
# keypoints for octave 1 [2, 434]
# keypoints for octave 1 [2, 435]
# keypoints for octave 1 [2, 466]
# keypoints for octave 1 [2, 467]
# keypoints for octave 1 [2, 468]
# keypoints for octave 1 [2, 470]
# keypoints for octave 1 [2, 471]
# keypoints for octave 1 [2, 472]
# keypoints for octave 1 [2, 476]
# keypoints for octave 1 [2, 477]
# keypoints for octave 1 [2, 478]
# keypoints for octave 1 [2, 479]
# keypoints for octave 1 [2, 485]
# keypoints for octave 1 [2, 486]
# keypoints for octave 1 [2, 487]
# keypoints for octave 1 [2, 488]
# keypoints for octave 1 [2, 489]
# keypoints for octave 1 [2, 492]
# keypoints for octave 1 [2, 493]
# keypoints for octave 1 [2, 494]
# keypoints for octave 1 [2, 495]
# keypoints for octave 1 [2, 496]
# keypoints for octave 1 [2, 512]
# keypoints for octave 1 [2, 513]
# keypoints for octave 1 [2, 514]
# keypoints for octave 1 [2, 515]
# keypoints for octave 1 [2, 516]
# keypoints for octave 1 [2, 517]
# keypoints for octave 1 [2, 522]
# keypoints for octave 1 [2, 523]
# keypoints for octave 1 [2, 524]
# keypoints for octave 1 [2, 525]
# keypoints for octave 1 [2, 526]
# keypoints for octave 1 [2, 527]
# keypoints for octave 1 [2, 539]
# keypoints for octave 1 [2, 540]
# keypoints for octave 1 [2, 541]
# keypoints for octave 1 [2, 542]
# keypoints for octave 1 [2, 544]
# keypoints for octave 1 [2, 545]
# keypoints for octave 1 [2, 546]
# keypoints for octave 1 [2, 548]
# keypoints for octave 1 [2, 549]
# keypoints for octave 1 [2, 550]
# keypoints for octave 1 [2, 556]
# keypoints for octave 1 [2, 557]
# keypoints for octave 1 [2, 558]
# keypoints for octave 1 [2, 562]
# keypoints for octave 1 [2, 563]
# keypoints for octave 1 [2, 564]
# keypoints for octave 1 [2, 565]
# keypoints for octave 1 [2, 566]
# keypoints for octave 1 [2, 567]
# keypoints for octave 1 [2, 571]
# keypoints for octave 1 [2, 572]
# keypoints for octave 1 [2, 573]
# keypoints for octave 1 [2, 574]
# keypoints for octave 1 [2, 575]
# keypoints for octave 1 [2, 577]
# keypoints for octave 1 [2, 578]
# keypoints for octave 1 [2, 579]
# keypoints for octave 1 [2, 581]
# keypoints for octave 1 [2, 582]
# keypoints for octave 1 [2, 583]
# keypoints for octave 1 [2, 584]
# keypoints for octave 1 [2, 585]
# keypoints for octave 1 [2, 586]
# keypoints for octave 1 [2, 587]
# keypoints for octave 1 [2, 588]
# keypoints for octave 1 [2, 589]
# keypoints for octave 1 [2, 590]
# keypoints for octave 1 [2, 591]
# keypoints for octave 1 [2, 592]
# keypoints for octave 1 [2, 593]
# keypoints for octave 1 [2, 594]
# keypoints for octave 1 [2, 595]
# keypoints for octave 1 [2, 596]
# keypoints for octave 1 [2, 597]
# keypoints for octave 1 [2, 598]
# keypoints for octave 1 [2, 599]
# keypoints for octave 1 [2, 600]
# keypoints for octave 1 [2, 601]
# keypoints for octave 1 [2, 606]
# keypoints for octave 1 [2, 607]
# keypoints for octave 1 [2, 608]
# keypoints for octave 1 [2, 609]
# keypoints for octave 1 [2, 610]
# keypoints for octave 1 [2, 611]
# keypoints for octave 1 [2, 612]
# keypoints for octave 1 [2, 613]
# keypoints for octave 1 [2, 614]
# keypoints for octave 1 [2, 615]
# keypoints for octave 1 [2, 616]
# keypoints for octave 1 [2, 617]
# keypoints for octave 1 [2, 618]
# keypoints for octave 1 [2, 619]
# keypoints for octave 1 [2, 620]
# keypoints for octave 1 [2, 621]
# keypoints for octave 1 [2, 622]
# keypoints for octave 1 [2, 623]
# keypoints for octave 1 [2, 624]
# keypoints for octave 1 [2, 625]
# keypoints for octave 1 [2, 626]
# keypoints for octave 1 [2, 627]
# keypoints for octave 1 [2, 628]
# keypoints for octave 1 [2, 629]
# keypoints for octave 1 [2, 630]
# keypoints for octave 1 [2, 631]
# keypoints for octave 1 [2, 632]
# keypoints for octave 1 [2, 633]
# keypoints for octave 1 [2, 634]
# keypoints for octave 1 [2, 635]
# keypoints for octave 1 [2, 636]
# keypoints for octave 1 [2, 637]
# keypoints for octave 1 [2, 638]
# keypoints for octave 1 [2, 639]
# keypoints for octave 1 [2, 640]
# keypoints for octave 1 [2, 641]
# keypoints for octave 1 [2, 642]
# keypoints for octave 1 [2, 643]
# keypoints for octave 1 [2, 644]
# keypoints for octave 1 [2, 645]
# keypoints for octave 1 [2, 646]
# keypoints for octave 1 [2, 647]
# keypoints for octave 1 [2, 648]
# keypoints for octave 1 [2, 649]
# keypoints for octave 1 [2, 650]
# keypoints for octave 1 [2, 651]
# keypoints for octave 1 [2, 652]
# keypoints for octave 1 [2, 653]
# keypoints for octave 1 [2, 654]
# keypoints for octave 1 [2, 655]
# keypoints for octave 1 [2, 656]
# keypoints for octave 1 [2, 657]
# keypoints for octave 1 [2, 658]
# keypoints for octave 1 [2, 659]
# keypoints for octave 1 [2, 660]
# keypoints for octave 1 [2, 661]
# keypoints for octave 1 [2, 662]
# keypoints for octave 1 [2, 667]
# keypoints for octave 1 [2, 668]
# keypoints for octave 1 [2, 669]
# keypoints for octave 1 [2, 670]
# keypoints for octave 1 [2, 671]
# keypoints for octave 1 [2, 672]
# keypoints for octave 1 [2, 673]
# keypoints for octave 1 [2, 674]
# keypoints for octave 1 [2, 675]
# keypoints for octave 1 [2, 676]
# keypoints for octave 1 [2, 677]
# keypoints for octave 1 [2, 678]
# keypoints for octave 1 [2, 679]
# keypoints for octave 1 [2, 680]
# keypoints for octave 1 [2, 681]
# keypoints for octave 1 [2, 682]
# keypoints for octave 1 [2, 683]
# keypoints for octave 1 [2, 684]
# keypoints for octave 1 [2, 685]
# keypoints for octave 1 [2, 686]
# keypoints for octave 1 [2, 687]
# keypoints for octave 1 [2, 688]
# keypoints for octave 1 [2, 689]
# keypoints for octave 1 [2, 690]
# keypoints for octave 1 [2, 691]
# keypoints for octave 1 [2, 692]
# keypoints for octave 1 [2, 693]
# keypoints for octave 1 [2, 694]
# keypoints for octave 1 [2, 695]
# keypoints for octave 1 [2, 696]
# keypoints for octave 1 [2, 697]
# keypoints for octave 1 [2, 698]
# keypoints for octave 1 [2, 699]
# keypoints for octave 1 [2, 700]
# keypoints for octave 1 [2, 701]
# keypoints for octave 1 [2, 702]
# keypoints for octave 1 [2, 703]
# keypoints for octave 1 [2, 704]
# keypoints for octave 1 [2, 705]
# keypoints for octave 1 [2, 706]
# keypoints for octave 1 [2, 707]
# keypoints for octave 1 [2, 708]
# keypoints for octave 1 [2, 709]
# keypoints for octave 1 [2, 710]
# keypoints for octave 1 [2, 711]
# keypoints for octave 1 [2, 712]
# keypoints for octave 1 [2, 713]
# keypoints for octave 1 [2, 714]
# keypoints for octave 1 [2, 715]
# keypoints for octave 1 [2, 716]
# keypoints for octave 1 [2, 717]
# keypoints for octave 1 [2, 718]
# keypoints for octave 1 [2, 719]
# keypoints for octave 1 [2, 720]
# keypoints for octave 1 [2, 721]
# keypoints for octave 1 [2, 722]
# keypoints for octave 1 [2, 723]
# keypoints for octave 1 [2, 724]
# keypoints for octave 1 [2, 725]
# keypoints for octave 1 [2, 726]
# keypoints for octave 1 [2, 727]
# keypoints for octave 1 [2, 728]
# keypoints for octave 1 [2, 729]
# keypoints for octave 1 [2, 730]
# keypoints for octave 1 [2, 731]
# keypoints for octave 1 [2, 732]
# keypoints for octave 1 [2, 733]
# keypoints for octave 1 [2, 734]
# keypoints for octave 1 [2, 735]
# keypoints for octave 1 [2, 736]
# keypoints for octave 1 [2, 737]
# keypoints for octave 1 [2, 738]
# keypoints for octave 1 [2, 741]
# keypoints for octave 1 [2, 742]
# keypoints for octave 1 [2, 743]
# keypoints for octave 1 [2, 744]
# keypoints for octave 1 [2, 745]
# keypoints for octave 1 [2, 746]
# keypoints for octave 1 [2, 747]
# keypoints for octave 1 [2, 748]
# keypoints for octave 1 [3, 1]
# keypoints for octave 1 [3, 2]
# keypoints for octave 1 [3, 28]
# keypoints for octave 1 [3, 41]
# keypoints for octave 1 [3, 42]
# keypoints for octave 1 [3, 43]
# keypoints for octave 1 [3, 44]
# keypoints for octave 1 [3, 45]
# keypoints for octave 1 [3, 47]
# keypoints for octave 1 [3, 48]
# keypoints for octave 1 [3, 57]
# keypoints for octave 1 [3, 58]
# keypoints for octave 1 [3, 59]
# keypoints for octave 1 [3, 61]
# keypoints for octave 1 [3, 63]
# keypoints for octave 1 [3, 73]
# keypoints for octave 1 [3, 75]
# keypoints for octave 1 [3, 76]
# keypoints for octave 1 [3, 77]
# keypoints for octave 1 [3, 82]
# keypoints for octave 1 [3, 83]
# keypoints for octave 1 [3, 84]
# keypoints for octave 1 [3, 85]
# keypoints for octave 1 [3, 89]
# keypoints for octave 1 [3, 90]
# keypoints for octave 1 [3, 94]
# keypoints for octave 1 [3, 100]
# keypoints for octave 1 [3, 101]
# keypoints for octave 1 [3, 111]
# keypoints for octave 1 [3, 112]
# keypoints for octave 1 [3, 113]
# keypoints for octave 1 [3, 114]
# keypoints for octave 1 [3, 115]
# keypoints for octave 1 [3, 117]
# keypoints for octave 1 [3, 124]
# keypoints for octave 1 [3, 132]
# keypoints for octave 1 [3, 133]
# keypoints for octave 1 [3, 139]
# keypoints for octave 1 [3, 159]
# keypoints for octave 1 [3, 160]
# keypoints for octave 1 [3, 167]
# keypoints for octave 1 [3, 168]
# keypoints for octave 1 [3, 170]
# keypoints for octave 1 [3, 173]
# keypoints for octave 1 [3, 219]
# keypoints for octave 1 [3, 226]
# keypoints for octave 1 [3, 244]
# keypoints for octave 1 [3, 245]
# keypoints for octave 1 [3, 269]
# keypoints for octave 1 [3, 273]
# keypoints for octave 1 [3, 278]
# keypoints for octave 1 [3, 286]
# keypoints for octave 1 [3, 287]
# keypoints for octave 1 [3, 289]
# keypoints for octave 1 [3, 295]
# keypoints for octave 1 [3, 317]
# keypoints for octave 1 [3, 318]
# keypoints for octave 1 [3, 323]
# keypoints for octave 1 [3, 325]
# keypoints for octave 1 [3, 337]
# keypoints for octave 1 [3, 338]
# keypoints for octave 1 [3, 344]
# keypoints for octave 1 [3, 345]
# keypoints for octave 1 [3, 355]
# keypoints for octave 1 [3, 358]
# keypoints for octave 1 [3, 361]
# keypoints for octave 1 [3, 363]
# keypoints for octave 1 [3, 364]
# keypoints for octave 1 [3, 365]
# keypoints for octave 1 [3, 366]
# keypoints for octave 1 [3, 369]
# keypoints for octave 1 [3, 372]
# keypoints for octave 1 [3, 387]
# keypoints for octave 1 [3, 388]
# keypoints for octave 1 [3, 394]
# keypoints for octave 1 [3, 397]
# keypoints for octave 1 [3, 427]
# keypoints for octave 1 [3, 435]
# keypoints for octave 1 [3, 437]
# keypoints for octave 1 [3, 452]
# keypoints for octave 1 [3, 464]
# keypoints for octave 1 [3, 471]
# keypoints for octave 1 [3, 477]
# keypoints for octave 1 [3, 488]
# keypoints for octave 1 [3, 510]
# keypoints for octave 1 [3, 516]
# keypoints for octave 1 [3, 522]
# keypoints for octave 1 [3, 523]
# keypoints for octave 1 [3, 537]
# keypoints for octave 1 [3, 545]
# keypoints for octave 1 [3, 549]
# keypoints for octave 1 [3, 578]
# keypoints for octave 1 [3, 603]
# keypoints for octave 1 [3, 604]
# keypoints for octave 1 [3, 605]
# keypoints for octave 1 [3, 661]
# keypoints for octave 1 [3, 709]
# keypoints for octave 1 [3, 739]
# keypoints for octave 1 [3, 740]
# keypoints for octave 1 [3, 741]
# keypoints for octave 1 [3, 747]
# keypoints for octave 1 [3, 748]
# keypoints for octave 1 [4, 1]
# keypoints for octave 1 [4, 2]
# keypoints for octave 1 [4, 34]
# keypoints for octave 1 [4, 42]
# keypoints for octave 1 [4, 43]
# keypoints for octave 1 [4, 44]
# keypoints for octave 1 [4, 45]
# keypoints for octave 1 [4, 53]
# keypoints for octave 1 [4, 58]
# keypoints for octave 1 [4, 59]
# keypoints for octave 1 [4, 60]
# keypoints for octave 1 [4, 61]
# keypoints for octave 1 [4, 64]
# keypoints for octave 1 [4, 72]
# keypoints for octave 1 [4, 76]
# keypoints for octave 1 [4, 77]
# keypoints for octave 1 [4, 82]
# keypoints for octave 1 [4, 83]
# keypoints for octave 1 [4, 85]
# keypoints for octave 1 [4, 87]
# keypoints for octave 1 [4, 89]
# keypoints for octave 1 [4, 90]
# keypoints for octave 1 [4, 91]
# keypoints for octave 1 [4, 94]
# keypoints for octave 1 [4, 98]
# keypoints for octave 1 [4, 100]
# keypoints for octave 1 [4, 108]
# keypoints for octave 1 [4, 110]
# keypoints for octave 1 [4, 112]
# keypoints for octave 1 [4, 114]
# keypoints for octave 1 [4, 122]
# keypoints for octave 1 [4, 126]
# keypoints for octave 1 [4, 139]
# keypoints for octave 1 [4, 165]
# keypoints for octave 1 [4, 168]
# keypoints for octave 1 [4, 174]
# keypoints for octave 1 [4, 175]
# keypoints for octave 1 [4, 181]
# keypoints for octave 1 [4, 185]
# keypoints for octave 1 [4, 213]
# keypoints for octave 1 [4, 221]
# keypoints for octave 1 [4, 225]
# keypoints for octave 1 [4, 226]
# keypoints for octave 1 [4, 227]
# keypoints for octave 1 [4, 247]
# keypoints for octave 1 [4, 258]
# keypoints for octave 1 [4, 263]
# keypoints for octave 1 [4, 264]
# keypoints for octave 1 [4, 269]
# keypoints for octave 1 [4, 285]
# keypoints for octave 1 [4, 286]
# keypoints for octave 1 [4, 295]
# keypoints for octave 1 [4, 299]
# keypoints for octave 1 [4, 311]
# keypoints for octave 1 [4, 312]
# keypoints for octave 1 [4, 313]
# keypoints for octave 1 [4, 321]
# keypoints for octave 1 [4, 324]
# keypoints for octave 1 [4, 338]
# keypoints for octave 1 [4, 339]
# keypoints for octave 1 [4, 342]
# keypoints for octave 1 [4, 344]
# keypoints for octave 1 [4, 351]
# keypoints for octave 1 [4, 356]
# keypoints for octave 1 [4, 362]
# keypoints for octave 1 [4, 364]
# keypoints for octave 1 [4, 371]
# keypoints for octave 1 [4, 388]
# keypoints for octave 1 [4, 397]
# keypoints for octave 1 [4, 402]
# keypoints for octave 1 [4, 403]
# keypoints for octave 1 [4, 416]
# keypoints for octave 1 [4, 427]
# keypoints for octave 1 [4, 434]
# keypoints for octave 1 [4, 451]
# keypoints for octave 1 [4, 458]
# keypoints for octave 1 [4, 470]
# keypoints for octave 1 [4, 479]
# keypoints for octave 1 [4, 480]
# keypoints for octave 1 [4, 483]
# keypoints for octave 1 [4, 485]
# keypoints for octave 1 [4, 493]
# keypoints for octave 1 [4, 506]
# keypoints for octave 1 [4, 518]
# keypoints for octave 1 [4, 522]
# keypoints for octave 1 [4, 528]
# keypoints for octave 1 [4, 530]
# keypoints for octave 1 [4, 533]
# keypoints for octave 1 [4, 536]
# keypoints for octave 1 [4, 537]
# keypoints for octave 1 [4, 539]
# keypoints for octave 1 [4, 565]
# keypoints for octave 1 [4, 566]
# keypoints for octave 1 [4, 646]
# keypoints for octave 1 [4, 647]
# keypoints for octave 1 [4, 648]
# keypoints for octave 1 [4, 649]
# keypoints for octave 1 [4, 662]
# keypoints for octave 1 [4, 708]
# keypoints for octave 1 [4, 747]
# keypoints for octave 1 [4, 748]
# keypoints for octave 1 [5, 1]
# keypoints for octave 1 [5, 2]
# keypoints for octave 1 [5, 24]
# keypoints for octave 1 [5, 25]
# keypoints for octave 1 [5, 26]
# keypoints for octave 1 [5, 33]
# keypoints for octave 1 [5, 37]
# keypoints for octave 1 [5, 41]
# keypoints for octave 1 [5, 42]
# keypoints for octave 1 [5, 43]
# keypoints for octave 1 [5, 45]
# keypoints for octave 1 [5, 48]
# keypoints for octave 1 [5, 53]
# keypoints for octave 1 [5, 54]
# keypoints for octave 1 [5, 57]
# keypoints for octave 1 [5, 60]
# keypoints for octave 1 [5, 68]
# keypoints for octave 1 [5, 69]
# keypoints for octave 1 [5, 70]
# keypoints for octave 1 [5, 77]
# keypoints for octave 1 [5, 78]
# keypoints for octave 1 [5, 79]
# keypoints for octave 1 [5, 85]
# keypoints for octave 1 [5, 87]
# keypoints for octave 1 [5, 96]
# keypoints for octave 1 [5, 101]
# keypoints for octave 1 [5, 103]
# keypoints for octave 1 [5, 113]
# keypoints for octave 1 [5, 114]
# keypoints for octave 1 [5, 124]
# keypoints for octave 1 [5, 125]
# keypoints for octave 1 [5, 126]
# keypoints for octave 1 [5, 139]
# keypoints for octave 1 [5, 152]
# keypoints for octave 1 [5, 153]
# keypoints for octave 1 [5, 155]
# ...
# keypoints for octave 3 [1, 84]
# keypoints for octave 3 [1, 85]
# keypoints for octave 3 [1, 86]
# keypoints for octave 3 [1, 87]
# keypoints for octave 3 [1, 88]
# keypoints for octave 3 [1, 89]
# keypoints for octave 3 [1, 90]
# keypoints for octave 3 [1, 91]
# keypoints for octave 3 [1, 92]
# keypoints for octave 3 [1, 93]
# keypoints for octave 3 [1, 94]
# keypoints for octave 3 [1, 95]
# keypoints for octave 3 [1, 96]
# keypoints for octave 3 [1, 97]
# keypoints for octave 3 [1, 98]
# keypoints for octave 3 [1, 99]
# keypoints for octave 3 [1, 100]
# keypoints for octave 3 [1, 101]
# keypoints for octave 3 [1, 102]
# keypoints for octave 3 [1, 103]
# keypoints for octave 3 [1, 104]
# keypoints for octave 3 [1, 105]
# keypoints for octave 3 [1, 106]
# keypoints for octave 3 [1, 107]
# keypoints for octave 3 [1, 108]
# keypoints for octave 3 [1, 109]
# keypoints for octave 3 [1, 110]
# keypoints for octave 3 [1, 111]
# keypoints for octave 3 [1, 112]
# keypoints for octave 3 [1, 113]
# keypoints for octave 3 [1, 114]
# keypoints for octave 3 [1, 115]
# keypoints for octave 3 [1, 116]
# keypoints for octave 3 [1, 117]
# keypoints for octave 3 [1, 118]
# keypoints for octave 3 [1, 119]
# keypoints for octave 3 [1, 120]
# keypoints for octave 3 [1, 121]
# keypoints for octave 3 [1, 122]
# keypoints for octave 3 [1, 123]
# keypoints for octave 3 [1, 124]
# keypoints for octave 3 [1, 125]
# keypoints for octave 3 [1, 126]
# keypoints for octave 3 [1, 127]
# keypoints for octave 3 [1, 128]
# keypoints for octave 3 [1, 129]
# keypoints for octave 3 [1, 130]
# keypoints for octave 3 [1, 131]
# keypoints for octave 3 [1, 132]
# keypoints for octave 3 [1, 133]
# keypoints for octave 3 [1, 134]
# keypoints for octave 3 [1, 135]
# keypoints for octave 3 [1, 136]
# keypoints for octave 3 [1, 137]
# keypoints for octave 3 [1, 138]
# keypoints for octave 3 [1, 139]
# keypoints for octave 3 [1, 140]
# keypoints for octave 3 [1, 141]
# keypoints for octave 3 [1, 142]
# keypoints for octave 3 [1, 143]
# keypoints for octave 3 [1, 144]
# keypoints for octave 3 [1, 145]
# keypoints for octave 3 [1, 146]
# keypoints for octave 3 [1, 147]
# keypoints for octave 3 [1, 148]
# keypoints for octave 3 [1, 149]
# keypoints for octave 3 [1, 150]
# keypoints for octave 3 [1, 151]
# keypoints for octave 3 [1, 152]
# keypoints for octave 3 [1, 153]
# keypoints for octave 3 [1, 154]
# keypoints for octave 3 [1, 155]
# keypoints for octave 3 [1, 156]
# keypoints for octave 3 [1, 157]
# keypoints for octave 3 [1, 158]
# keypoints for octave 3 [1, 159]
# keypoints for octave 3 [1, 160]
# keypoints for octave 3 [1, 161]
# keypoints for octave 3 [1, 162]
# keypoints for octave 3 [1, 163]
# keypoints for octave 3 [1, 164]
# keypoints for octave 3 [1, 165]
# keypoints for octave 3 [1, 166]
# keypoints for octave 3 [1, 167]
# keypoints for octave 3 [1, 168]
# keypoints for octave 3 [1, 169]
# keypoints for octave 3 [1, 170]
# keypoints for octave 3 [1, 171]
# keypoints for octave 3 [1, 172]
# keypoints for octave 3 [1, 173]
# keypoints for octave 3 [1, 174]
# keypoints for octave 3 [1, 175]
# keypoints for octave 3 [1, 176]
# keypoints for octave 3 [1, 177]
# keypoints for octave 3 [1, 178]
# keypoints for octave 3 [1, 179]
# keypoints for octave 3 [1, 180]
# keypoints for octave 3 [1, 181]
# keypoints for octave 3 [1, 182]
# keypoints for octave 3 [1, 183]
# keypoints for octave 3 [1, 184]
# keypoints for octave 3 [1, 185]
# keypoints for octave 3 [1, 186]
# keypoints for octave 3 [2, 1]
# keypoints for octave 3 [2, 2]
# keypoints for octave 3 [2, 3]
# keypoints for octave 3 [2, 184]
# keypoints for octave 3 [2, 185]
# keypoints for octave 3 [2, 186]
# keypoints for octave 3 [3, 1]
# keypoints for octave 3 [3, 2]
# keypoints for octave 3 [3, 23]
# keypoints for octave 3 [3, 35]
# keypoints for octave 3 [3, 45]
# keypoints for octave 3 [3, 47]
# keypoints for octave 3 [3, 61]
# keypoints for octave 3 [3, 98]
# keypoints for octave 3 [3, 104]
# keypoints for octave 3 [3, 105]
# keypoints for octave 3 [3, 112]
# keypoints for octave 3 [3, 113]
# keypoints for octave 3 [3, 114]
# keypoints for octave 3 [3, 118]
# keypoints for octave 3 [3, 142]
# keypoints for octave 3 [3, 155]
# keypoints for octave 3 [3, 162]
# keypoints for octave 3 [3, 185]
# keypoints for octave 3 [3, 186]
# keypoints for octave 3 [4, 1]
# keypoints for octave 3 [4, 2]
# keypoints for octave 3 [4, 21]
# keypoints for octave 3 [4, 23]
# keypoints for octave 3 [4, 24]
# keypoints for octave 3 [4, 36]
# keypoints for octave 3 [4, 37]
# keypoints for octave 3 [4, 38]
# keypoints for octave 3 [4, 41]
# keypoints for octave 3 [4, 45]
# keypoints for octave 3 [4, 98]
# keypoints for octave 3 [4, 106]
# keypoints for octave 3 [4, 107]
# keypoints for octave 3 [4, 109]
# keypoints for octave 3 [4, 110]
# keypoints for octave 3 [4, 112]
# keypoints for octave 3 [4, 128]
# keypoints for octave 3 [4, 141]
# keypoints for octave 3 [4, 147]
# keypoints for octave 3 [4, 148]
# keypoints for octave 3 [4, 155]
# keypoints for octave 3 [4, 185]
# keypoints for octave 3 [4, 186]
# keypoints for octave 3 [5, 1]
# keypoints for octave 3 [5, 2]
# keypoints for octave 3 [5, 41]
# keypoints for octave 3 [5, 73]
# keypoints for octave 3 [5, 87]
# keypoints for octave 3 [5, 99]
# keypoints for octave 3 [5, 107]
# keypoints for octave 3 [5, 108]
# keypoints for octave 3 [5, 109]
# keypoints for octave 3 [5, 110]
# keypoints for octave 3 [5, 111]
# keypoints for octave 3 [5, 113]
# keypoints for octave 3 [5, 127]
# keypoints for octave 3 [5, 158]
# keypoints for octave 3 [5, 165]
# keypoints for octave 3 [5, 185]
# keypoints for octave 3 [5, 186]
# start
# end
# start
# end
# start
# end
# start
# end
# keypoints for octave 4 [1, 1]
# keypoints for octave 4 [1, 2]
# keypoints for octave 4 [1, 3]
# keypoints for octave 4 [1, 4]
# keypoints for octave 4 [1, 5]
# keypoints for octave 4 [1, 6]
# keypoints for octave 4 [1, 7]
# keypoints for octave 4 [1, 8]
# keypoints for octave 4 [1, 9]
# keypoints for octave 4 [1, 10]
# keypoints for octave 4 [1, 11]
# keypoints for octave 4 [1, 12]
# keypoints for octave 4 [1, 13]
# keypoints for octave 4 [1, 14]
# keypoints for octave 4 [1, 15]
# keypoints for octave 4 [1, 16]
# keypoints for octave 4 [1, 17]
# keypoints for octave 4 [1, 18]
# keypoints for octave 4 [1, 19]
# keypoints for octave 4 [1, 20]
# keypoints for octave 4 [1, 21]
# keypoints for octave 4 [1, 22]
# keypoints for octave 4 [1, 23]
# keypoints for octave 4 [1, 24]
# keypoints for octave 4 [1, 25]
# keypoints for octave 4 [1, 26]
# keypoints for octave 4 [1, 27]
# keypoints for octave 4 [1, 28]
# keypoints for octave 4 [1, 29]
# keypoints for octave 4 [1, 30]
# keypoints for octave 4 [1, 31]
# keypoints for octave 4 [1, 32]
# keypoints for octave 4 [1, 33]
# keypoints for octave 4 [1, 34]
# keypoints for octave 4 [1, 35]
# keypoints for octave 4 [1, 36]
# keypoints for octave 4 [1, 37]
# keypoints for octave 4 [1, 38]
# keypoints for octave 4 [1, 39]
# keypoints for octave 4 [1, 40]
# keypoints for octave 4 [1, 41]
# keypoints for octave 4 [1, 42]
# keypoints for octave 4 [1, 43]
# keypoints for octave 4 [1, 44]
# keypoints for octave 4 [1, 45]
# keypoints for octave 4 [1, 46]
# keypoints for octave 4 [1, 47]
# keypoints for octave 4 [1, 48]
# keypoints for octave 4 [1, 49]
# keypoints for octave 4 [1, 50]
# keypoints for octave 4 [1, 51]
# keypoints for octave 4 [1, 52]
# keypoints for octave 4 [1, 53]
# keypoints for octave 4 [1, 54]
# keypoints for octave 4 [1, 55]
# keypoints for octave 4 [1, 56]
# keypoints for octave 4 [1, 57]
# keypoints for octave 4 [1, 58]
# keypoints for octave 4 [1, 59]
# keypoints for octave 4 [1, 60]
# keypoints for octave 4 [1, 61]
# keypoints for octave 4 [1, 62]
# keypoints for octave 4 [1, 63]
# keypoints for octave 4 [1, 64]
# keypoints for octave 4 [1, 65]
# keypoints for octave 4 [1, 66]
# keypoints for octave 4 [1, 67]
# keypoints for octave 4 [1, 68]
# keypoints for octave 4 [1, 69]
# keypoints for octave 4 [1, 70]
# keypoints for octave 4 [1, 71]
# keypoints for octave 4 [1, 72]
# keypoints for octave 4 [1, 73]
# keypoints for octave 4 [1, 74]
# keypoints for octave 4 [1, 75]
# keypoints for octave 4 [1, 76]
# keypoints for octave 4 [1, 77]
# keypoints for octave 4 [1, 78]
# keypoints for octave 4 [1, 79]
# keypoints for octave 4 [1, 80]
# keypoints for octave 4 [1, 81]
# keypoints for octave 4 [1, 82]
# keypoints for octave 4 [1, 83]
# keypoints for octave 4 [1, 84]
# keypoints for octave 4 [1, 85]
# keypoints for octave 4 [1, 86]
# keypoints for octave 4 [1, 87]
# keypoints for octave 4 [1, 88]
# keypoints for octave 4 [1, 89]
# keypoints for octave 4 [1, 90]
# keypoints for octave 4 [1, 91]
# keypoints for octave 4 [1, 92]
# keypoints for octave 4 [2, 1]
# keypoints for octave 4 [2, 2]
# keypoints for octave 4 [2, 3]
# keypoints for octave 4 [2, 90]
# keypoints for octave 4 [2, 91]
# keypoints for octave 4 [2, 92]
# keypoints for octave 4 [3, 1]
# keypoints for octave 4 [3, 2]
# keypoints for octave 4 [3, 4]
# keypoints for octave 4 [3, 5]
# keypoints for octave 4 [3, 6]
# keypoints for octave 4 [3, 10]
# keypoints for octave 4 [3, 12]
# keypoints for octave 4 [3, 13]
# keypoints for octave 4 [3, 20]
# keypoints for octave 4 [3, 21]
# keypoints for octave 4 [3, 22]
# keypoints for octave 4 [3, 29]
# keypoints for octave 4 [3, 30]
# keypoints for octave 4 [3, 32]
# keypoints for octave 4 [3, 51]
# keypoints for octave 4 [3, 52]
# keypoints for octave 4 [3, 55]
# keypoints for octave 4 [3, 56]
# keypoints for octave 4 [3, 57]
# keypoints for octave 4 [3, 58]
# keypoints for octave 4 [3, 67]
# keypoints for octave 4 [3, 68]
# keypoints for octave 4 [3, 69]
# keypoints for octave 4 [3, 79]
# keypoints for octave 4 [3, 80]
# keypoints for octave 4 [3, 81]
# keypoints for octave 4 [3, 82]
# keypoints for octave 4 [3, 83]
# keypoints for octave 4 [3, 88]
# keypoints for octave 4 [3, 91]
# keypoints for octave 4 [3, 92]
# keypoints for octave 4 [4, 1]
# keypoints for octave 4 [4, 2]
# keypoints for octave 4 [4, 4]
# keypoints for octave 4 [4, 6]
# keypoints for octave 4 [4, 12]
# keypoints for octave 4 [4, 18]
# keypoints for octave 4 [4, 20]
# keypoints for octave 4 [4, 21]
# keypoints for octave 4 [4, 47]
# keypoints for octave 4 [4, 58]
# keypoints for octave 4 [4, 63]
# keypoints for octave 4 [4, 71]
# keypoints for octave 4 [4, 77]
# keypoints for octave 4 [4, 80]
# keypoints for octave 4 [4, 81]
# keypoints for octave 4 [4, 83]
# keypoints for octave 4 [4, 84]
# keypoints for octave 4 [4, 91]
# keypoints for octave 4 [4, 92]
# keypoints for octave 4 [5, 1]
# keypoints for octave 4 [5, 2]
# keypoints for octave 4 [5, 5]
# keypoints for octave 4 [5, 7]
# keypoints for octave 4 [5, 10]
# keypoints for octave 4 [5, 11]
# keypoints for octave 4 [5, 12]
# keypoints for octave 4 [5, 13]
# keypoints for octave 4 [5, 18]
# keypoints for octave 4 [5, 29]
# keypoints for octave 4 [5, 33]
# keypoints for octave 4 [5, 34]
# keypoints for octave 4 [5, 36]
# keypoints for octave 4 [5, 46]
# keypoints for octave 4 [5, 60]
# keypoints for octave 4 [5, 69]
# keypoints for octave 4 [5, 72]
# keypoints for octave 4 [5, 82]
# keypoints for octave 4 [5, 83]
# keypoints for octave 4 [5, 84]
# keypoints for octave 4 [5, 85]
# keypoints for octave 4 [5, 87]
# keypoints for octave 4 [5, 89]
# keypoints for octave 4 [5, 90]
# keypoints for octave 4 [5, 91]
# keypoints for octave 4 [5, 92]
# keypoints for octave 4 [1, 1]
# keypoints for octave 4 [1, 2]
# keypoints for octave 4 [1, 3]
# keypoints for octave 4 [1, 4]
# keypoints for octave 4 [1, 5]
# keypoints for octave 4 [1, 6]
# keypoints for octave 4 [1, 7]
# keypoints for octave 4 [1, 8]
# keypoints for octave 4 [1, 9]
# keypoints for octave 4 [1, 10]
# keypoints for octave 4 [1, 11]
# keypoints for octave 4 [1, 12]
# keypoints for octave 4 [1, 13]
# keypoints for octave 4 [1, 14]
# keypoints for octave 4 [1, 15]
# keypoints for octave 4 [1, 16]
# keypoints for octave 4 [1, 17]
# keypoints for octave 4 [1, 18]
# keypoints for octave 4 [1, 19]
# keypoints for octave 4 [1, 20]
# keypoints for octave 4 [1, 21]
# keypoints for octave 4 [1, 22]
# keypoints for octave 4 [1, 23]
# keypoints for octave 4 [1, 24]
# keypoints for octave 4 [1, 25]
# keypoints for octave 4 [1, 26]
# keypoints for octave 4 [1, 27]
# keypoints for octave 4 [1, 28]
# keypoints for octave 4 [1, 29]
# keypoints for octave 4 [1, 30]
# keypoints for octave 4 [1, 31]
# keypoints for octave 4 [1, 32]
# keypoints for octave 4 [1, 33]
# keypoints for octave 4 [1, 34]
# keypoints for octave 4 [1, 35]
# keypoints for octave 4 [1, 36]
# keypoints for octave 4 [1, 37]
# keypoints for octave 4 [1, 38]
# keypoints for octave 4 [1, 39]
# keypoints for octave 4 [1, 40]
# keypoints for octave 4 [1, 41]
# keypoints for octave 4 [1, 42]
# keypoints for octave 4 [1, 43]
# keypoints for octave 4 [1, 44]
# keypoints for octave 4 [1, 45]
# keypoints for octave 4 [1, 46]
# keypoints for octave 4 [1, 47]
# keypoints for octave 4 [1, 48]
# keypoints for octave 4 [1, 49]
# keypoints for octave 4 [1, 50]
# keypoints for octave 4 [1, 51]
# keypoints for octave 4 [1, 52]
# keypoints for octave 4 [1, 53]
# keypoints for octave 4 [1, 54]
# keypoints for octave 4 [1, 55]
# keypoints for octave 4 [1, 56]
# keypoints for octave 4 [1, 57]
# keypoints for octave 4 [1, 58]
# keypoints for octave 4 [1, 59]
# keypoints for octave 4 [1, 60]
# keypoints for octave 4 [1, 61]
# keypoints for octave 4 [1, 62]
# keypoints for octave 4 [1, 63]
# keypoints for octave 4 [1, 64]
# keypoints for octave 4 [1, 65]
# keypoints for octave 4 [1, 66]
# keypoints for octave 4 [1, 67]
# keypoints for octave 4 [1, 68]
# keypoints for octave 4 [1, 69]
# keypoints for octave 4 [1, 70]
# keypoints for octave 4 [1, 71]
# keypoints for octave 4 [1, 72]
# keypoints for octave 4 [1, 73]
# keypoints for octave 4 [1, 74]
# keypoints for octave 4 [1, 75]
# keypoints for octave 4 [1, 76]
# keypoints for octave 4 [1, 77]
# keypoints for octave 4 [1, 78]
# keypoints for octave 4 [1, 79]
# keypoints for octave 4 [1, 80]
# keypoints for octave 4 [1, 81]
# keypoints for octave 4 [1, 82]
# keypoints for octave 4 [1, 83]
# keypoints for octave 4 [1, 84]
# keypoints for octave 4 [1, 85]
# keypoints for octave 4 [1, 86]
# keypoints for octave 4 [1, 87]
# keypoints for octave 4 [1, 88]
# keypoints for octave 4 [1, 89]
# keypoints for octave 4 [1, 90]
# keypoints for octave 4 [1, 91]
# keypoints for octave 4 [1, 92]
# keypoints for octave 4 [2, 1]
# keypoints for octave 4 [2, 2]
# keypoints for octave 4 [2, 3]
# keypoints for octave 4 [2, 90]
# keypoints for octave 4 [2, 91]
# keypoints for octave 4 [2, 92]
# keypoints for octave 4 [3, 1]
# keypoints for octave 4 [3, 2]
# keypoints for octave 4 [3, 9]
# keypoints for octave 4 [3, 11]
# keypoints for octave 4 [3, 18]
# keypoints for octave 4 [3, 21]
# keypoints for octave 4 [3, 26]
# keypoints for octave 4 [3, 27]
# keypoints for octave 4 [3, 53]
# keypoints for octave 4 [3, 61]
# keypoints for octave 4 [3, 68]
# keypoints for octave 4 [3, 69]
# keypoints for octave 4 [3, 71]
# keypoints for octave 4 [3, 72]
# keypoints for octave 4 [3, 75]
# keypoints for octave 4 [3, 76]
# keypoints for octave 4 [3, 77]
# keypoints for octave 4 [3, 78]
# keypoints for octave 4 [3, 81]
# keypoints for octave 4 [3, 82]
# keypoints for octave 4 [3, 87]
# keypoints for octave 4 [3, 91]
# keypoints for octave 4 [3, 92]
# keypoints for octave 4 [4, 1]
# keypoints for octave 4 [4, 2]
# keypoints for octave 4 [4, 5]
# keypoints for octave 4 [4, 11]
# keypoints for octave 4 [4, 12]
# keypoints for octave 4 [4, 13]
# keypoints for octave 4 [4, 14]
# keypoints for octave 4 [4, 18]
# keypoints for octave 4 [4, 21]
# keypoints for octave 4 [4, 25]
# keypoints for octave 4 [4, 40]
# keypoints for octave 4 [4, 44]
# keypoints for octave 4 [4, 45]
# keypoints for octave 4 [4, 52]
# keypoints for octave 4 [4, 60]
# keypoints for octave 4 [4, 62]
# keypoints for octave 4 [4, 70]
# keypoints for octave 4 [4, 73]
# keypoints for octave 4 [4, 74]
# keypoints for octave 4 [4, 78]
# keypoints for octave 4 [4, 82]
# keypoints for octave 4 [4, 83]
# keypoints for octave 4 [4, 84]
# keypoints for octave 4 [4, 89]
# keypoints for octave 4 [4, 91]
# keypoints for octave 4 [4, 92]
# keypoints for octave 4 [5, 1]
# keypoints for octave 4 [5, 2]
# keypoints for octave 4 [5, 4]
# keypoints for octave 4 [5, 7]
# keypoints for octave 4 [5, 10]
# keypoints for octave 4 [5, 15]
# keypoints for octave 4 [5, 22]
# keypoints for octave 4 [5, 23]
# keypoints for octave 4 [5, 26]
# keypoints for octave 4 [5, 28]
# keypoints for octave 4 [5, 36]
# keypoints for octave 4 [5, 57]
# keypoints for octave 4 [5, 58]
# keypoints for octave 4 [5, 59]
# keypoints for octave 4 [5, 61]
# keypoints for octave 4 [5, 66]
# keypoints for octave 4 [5, 68]
# keypoints for octave 4 [5, 71]
# keypoints for octave 4 [5, 74]
# keypoints for octave 4 [5, 84]
# keypoints for octave 4 [5, 85]
# keypoints for octave 4 [5, 91]
# keypoints for octave 4 [5, 92]
# True
